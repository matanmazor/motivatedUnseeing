# %%
import json
import pandas as pd
import numpy as np
from os import path as path
import glob
import json

def to_csv(filename):
    dfs=[]
    with open(filename+'.txt') as json_file:
        for i,line in enumerate(json_file):
            if line[0:14]!='Consent given.':
                dfs.append(pd.read_json(line))


    group_df = pd.concat(dfs)
    group_df.to_csv(filename+'.csv', index=False)
    return(group_df)

# group_df = to_csv(path.join('..','experiments','pilots','letters','data','jatos_results_batch3'))

# %%
def to_csv_multiple_files(dirname):
    dfs=[]
    json_files = glob.glob(path.join(dirname,'*','*.json'))
    for i,file in enumerate(json_files):
                dfs.append(pd.read_json(file));
    group_df = pd.concat(dfs)
    group_df.to_csv(dirname+'/all_data.csv', index=False)
    return(group_df)

# %%
group_df=to_csv_multiple_files(path.join('..','experiments','gratings3','data','jatos_resultfiles_batch1'))

# %%
to_csv(path.join('..','experiments','pilots','loss','data','Clare'))
# Out:
#      success  timeout failed_images failed_audio failed_video  \
# 0        1.0      0.0            []           []           []
# 1        1.0      NaN           NaN          NaN          NaN
# 2        NaN      NaN           NaN          NaN          NaN
# 3        NaN      NaN           NaN          NaN          NaN
# 4        NaN      NaN           NaN          NaN          NaN
# ..       ...      ...           ...          ...          ...
# 409      NaN      NaN           NaN          NaN          NaN
# 410      NaN      NaN           NaN          NaN          NaN
# 411      NaN      NaN           NaN          NaN          NaN
# 412      NaN      NaN           NaN          NaN          NaN
# 413      NaN      NaN           NaN          NaN          NaN
#
#               trial_type  trial_index  time_elapsed  internal_node_id  \
# 0                preload            0           976           0.0-0.0
# 1             fullscreen            1          3890           0.0-1.0
# 2           instructions            2         20978       0.0-2.0-0.0
# 3    survey-multi-choice            3         27624       0.0-2.0-1.0
# 4           instructions            4         29204       0.0-3.0-0.0
# ..                   ...          ...           ...               ...
# 409          DiscGrating          409        498838  0.0-8.0-6.0-1.21
# 410         instructions          410        500182       0.0-8.0-7.0
# 411  survey-multi-choice          411        504706           0.0-9.0
# 412          survey-text          412        506362          0.0-10.0
# 413         instructions          413        507918          0.0-11.0
#
#                                           protocol_sum  ...     RT  \
# 0    ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 1    ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 2    ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 3    ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 4    ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# ..                                                 ...  ...    ...
# 409  ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...  691.2
# 410  ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 411  ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 412  ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
# 413  ec95deec6c5c5d972923c7127e3567b7d00e9086f29acf...  ...    NaN
#
#     measured_presentation_time measured_number_of_frames target_time  \
# 0                          NaN                       NaN         NaN
# 1                          NaN                       NaN         NaN
# 2                          NaN                       NaN         NaN
# 3                          NaN                       NaN         NaN
# 4                          NaN                       NaN         NaN
# ..                         ...                       ...         ...
# 409                       84.0                       5.0        80.0
# 410                        NaN                       NaN         NaN
# 411                        NaN                       NaN         NaN
# 412                        NaN                       NaN         NaN
# 413                        NaN                       NaN         NaN
#
#     orientation phase                     test_part  correct_response  \
# 0           NaN   NaN                           NaN               NaN
# 1           NaN   NaN                           NaN               NaN
# 2           NaN   NaN                           NaN               NaN
# 3           NaN   NaN                           NaN               NaN
# 4           NaN   NaN                           NaN               NaN
# ..          ...   ...                           ...               ...
# 409         ACW  69.0                         loss8                 f
# 410         NaN   NaN                           NaN               NaN
# 411         NaN   NaN  target_stimulus_memory_check               NaN
# 412         NaN   NaN                           NaN               NaN
# 413         NaN   NaN                           NaN               NaN
#
#      correct  target
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ..       ...     ...
# 409      1.0     1.0
# 410      NaN     NaN
# 411      1.0     NaN
# 412      NaN     NaN
# 413      NaN     NaN
#
# [414 rows x 41 columns]

# %%
group_df.response
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      {'multichoice_discrimination': 'press F when t...
# 4                                                    NaN
#                              ...
# 373                                                  NaN
# 374                                                  NaN
# 375    {'Prefer_not_to_think': '', 'Wonder_thoughts':...
# 376    {'worker_comments': 'This was fun, but pretty ...
# 377                                                  NaN
# Name: response, Length: 28094, dtype: object
